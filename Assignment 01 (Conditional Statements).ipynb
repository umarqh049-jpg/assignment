# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
# User se salary aur years of service input lena
salary = float (input("Apni salary darj karein: "))
years_of_service = int(input("Apne saal-e-service (years of service) darj karein: "))

# Bonus ki calculation
if years_of_service > 5:
    # 5% bonus calculate karna
    bonus_amount = salary * 0.05
    print(f"congrates! Aapka net bonus amount hai: {bonus_amount}")
else:
    print("Shorry, aapka year of service 5 saal se kam hai, isliye koi bonus nahi hai.")
# Out:
# congrates! Aapka net bonus amount hai: 50.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
# Accept age from the user and convert it to an integer
age = int(input("Enter your age: "))

# Check if the person is eligible for voting
if age > 17:
    print("You are eligible for voting.")
else:
    print("You are not eligible for voting.")
# Out:
# You are not eligible for voting.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
# Accept a number from the user and convert it to an integer
number = int(input("Enter a number: "))

# Check if the number is divisible by 2
if number % 2 == 0:
    print(f"{number} is an Even number.")
else:
    print(f"{number} is an Odd number.")
# Out:
# 47 is an Odd number.

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Input: Get a number from the user
number = int(input("Enter a number: "))

# Check if the remainder is 0 when divided by 7
if number % 7 == 0:
    print(f"{number} is divisible by 7.")
else:
    print(f"{number} is not divisible by 7.")
# Out:
# 67 is not divisible by 7.

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Take input from the user and convert it to an integer
number = int(input("Enter a number: "))

# Check if the number is a multiple of 5
if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
# Take length and breadth input from the user
length = float(input("Enter the length: "))
breadth = float(input("Enter the breadth: "))

# Check if length and breadth are equal
if length == breadth:
    print("It is a square.")
else:
    print("It is a rectangle.")
# Out:
# It is a rectangle.

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
# Take two integer inputs from the user
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

# Compare the two numbers
if number1 > number2:
    print(f"The greatest number is: {number1}")
elif number2 > number1:
    print(f"The greatest number is: {number2}")
else:
    print("Both numbers are equal.")
# Out:
# The greatest number is: 95

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
# Take marks input from the user
marks = float(input("Enter your marks: "))

# Determine the grade based on the school rules
if marks < 25:
    grade = "F"
elif marks >= 25 and marks < 45:
    grade = "E"
elif marks >= 45 and marks < 50:
    grade = "D"
elif marks >= 50 and marks < 60:
    grade = "C"
elif marks >= 60 and marks <= 80:
    grade = "B"
else:
    grade = "A"

# Print the final grade
print(f"Your grade is: {grade}")
# Out:
# Your grade is: A

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
# Take inputs from the user
age = int(input("Enter age: "))
gender = input("Enter gender (M or F): ").upper()
marital_status = input("Enter marital status (Y or N): ").upper()

# Check the conditions for place of service
if age < 20 or age > 60:
    print("ERROR")
elif gender == "F":
    print("Place of service: Urban areas only")
elif gender == "M" and 20 <= age < 40:
    print("Place of service: Anywhere")
elif gender == "M" and 40 <= age <= 60:
    print("Place of service: Urban areas only")
else:
    print("ERROR")
# Out:
# ERROR
